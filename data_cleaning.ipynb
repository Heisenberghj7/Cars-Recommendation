# %% [markdown]
# ## 1- Data Discovery

# %%
import pandas as pd

# %%
pd.set_option('display.max_row', 111)
pd.set_option('display.max_column', 82)

# %%
df=pd.read_csv("Cars_Data")
df.head()
# Out:
#                                        Brand & Model  \
# 0  ALFA ROMEO Giulia\n2.2 JTDM 190 AT8 Super\ncho...
# 1  ALFA ROMEO Giulia\n2.2 JTDM 190 AT8 Sprint\nch...
# 2  ALFA ROMEO Giulia\n2.9 V6 510 AT8 Q4 Quadrifog...
# 3  ALFA ROMEO Tonale\n1.6 Diesel 130 Sprint\nchoi...
# 4  ALFA ROMEO Tonale\n1.6 Diesel 130 TI\nchoisir ...
#
#                  Original Price         Promo               Moteur  Energie  \
# 0            455.000 DH * promo  420.000 DH *      2.2 JTD 190 TCT   Diesel
# 1            510.000 DH * promo  448.000 DH *      2.2 JTD 190 TCT   Diesel
# 2          1.008.000 DH * promo  918.000 DH *       2.9 V6 510 AT8  Essence
# 3  389.000 DH *   * Prix public           Nan  1.6 Diesel 130 TCT6   Diesel
# 4  429.000 DH *   * Prix public           Nan  1.6 Diesel 130 TCT6   Diesel
#
#            Architecture  Cylindrée Puissance fiscale Puissance maxi.  \
# 0  4 cylindres en ligne  2.143 cm³              8 cv          190 ch
# ...

# %%
df.shape
# Out:
# (887, 82)

# %%
df.dtypes.value_counts()
# Out:
# object     57
# float64    25
# dtype: int64

# %%
(df.isna().sum()/df.shape[0]).sort_values(ascending=True)
# Out:
# Brand & Model                                  0.000000
# Original Price                                 0.000000
# Promo                                          0.000000
# Ecran tactile                                  0.023675
# Frein à main électrique                        0.023675
# Allumage auto. des feux                        0.023675
# Détecteur de pluie                             0.023675
# Régulateur de vitesse adaptatif                0.023675
# Régulateur de vitesse                          0.023675
# Start & Stop                                   0.023675
# Ordinateur de bord                             0.023675
# Système audio                                  0.023675
# Climatisation                                  0.023675
# Préparation ISOFIX                             0.023675
# Phares antibrouillard                          0.023675
# Système d'alarme                               0.023675
# Détecteur de sous-gonflage                     0.023675
# ...

# %% [markdown]
# ## 2- Some Basic Cleaning

# %%
# We should know what the values look like in each column in order to know what type of cleaning they need
